# %%
import numpy as nm
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv("Car_sales.csv")

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df["Vehicle_type"].value_counts().plot(kind='pie',figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='Vehicle_type'>

# %%
df["Manufacturer"].value_counts().plot(kind='bar',figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
df["Engine_size"].value_counts().plot(kind='bar',figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
corr=df.corr()
corr
# Out:
#                      Sales_in_thousands  __year_resale_value  \
# Sales_in_thousands             1.000000            -0.279034
# __year_resale_value           -0.279034             1.000000
# Price_in_thousands            -0.304734             0.953840
# Engine_size                    0.019983             0.531330
# Horsepower                    -0.197756             0.769081
# Wheelbase                      0.358179            -0.052270
# Width                          0.140918             0.178767
# Length                         0.254980             0.026548
# Curb_weight                    0.008628             0.361557
# Fuel_capacity                  0.086540             0.325567
# Fuel_efficiency               -0.016764            -0.399880
# Power_perf_factor             -0.223252             0.827123
#
#                      Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# Sales_in_thousands            -0.304734     0.019983   -0.197756   0.358179
# ...

# %%
fig=plt.figure(figsize=(8,8))
plt.matshow(corr,cmap='RdBu')
plt.xticks(range(len(corr.columns)),corr.columns,rotation='vertical');
plt.yticks(range(len(corr.columns)),corr.columns);

# %%
df.loc[df['Manufacturer']=='BMW']
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 7          BMW  323i              19.747                  NaN    Passenger
# 8          BMW  328i               9.231               28.675    Passenger
# 9          BMW  528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
df["Price_in_thousands"].describe()
# Out:
# count    155.000000
# mean      27.390755
# std       14.351653
# min        9.235000
# 25%       18.017500
# 50%       22.799000
# 75%       31.947500
# max       85.500000
# Name: Price_in_thousands, dtype: float64

# %%
df["Model"].value_counts()
# Out:
# Neon          2
# Integra       1
# Cutlass       1
# Sentra        1
# Altima        1
#              ..
# Windstar      1
# Expedition    1
# Ranger        1
# F-Series      1
# S80           1
# Name: Model, Length: 156, dtype: int64

# %%
a=df.loc[df['Manufacturer']=='Dodge']
a
# Out:
#    Manufacturer       Model  Sales_in_thousands  __year_resale_value  \
# 35        Dodge        Neon              76.034                7.750
# 36        Dodge     Avenger               4.734               12.545
# 37        Dodge     Stratus              71.186               10.185
# 38        Dodge    Intrepid              88.028               12.275
# 39        Dodge       Viper               0.916               58.470
# 40        Dodge  Ram Pickup             227.061               15.060
# 41        Dodge   Ram Wagon              16.767               15.510
# 42        Dodge     Ram Van              31.038               13.425
# 43        Dodge      Dakota             111.313               11.260
# 44        Dodge     Durango             101.323                  NaN
# 45        Dodge     Caravan             181.749               12.025
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
df["Model"].value_counts()
# Out:
# Neon          2
# Integra       1
# Cutlass       1
# Sentra        1
# Altima        1
#              ..
# Windstar      1
# Expedition    1
# Ranger        1
# F-Series      1
# S80           1
# Name: Model, Length: 156, dtype: int64

# %%
milage=df.groupby("Fuel_capacity")["Fuel_efficiency"].max()

# %%
milage.head()
# Out:
# Fuel_capacity
# 10.3    45.0
# 11.9    32.0
# 12.0    21.0
# 12.1    33.0
# 12.5    29.0
# Name: Fuel_efficiency, dtype: float64

# %%
a=df.groupby("Engine_size")["Price_in_thousands"]
a.head()
# Out:
# 0      21.500
# 1      28.400
# 2         NaN
# 3      42.000
# 4      23.990
#         ...
# 143    22.288
# 144    51.728
# 151    23.400
# 152    24.400
# 156    36.000
# Name: Price_in_thousands, Length: 104, dtype: float64

# %%
df["Fuel_capacity"].value_counts().plot(kind='bar',figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df["Fuel_efficiency"].value_counts().plot(kind='bar',figsize=(10,5))
# Out:
# <AxesSubplot:>
